# %%
from langchain_community.document_loaders import WebBaseLoader
from pprint import pp

# %%
# create the loader

url_1 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader"
url_2 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfminer"
url_3 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber"

# WebBaseLoader()

# loader = WebBaseLoader(web_path=url_1)
loader = WebBaseLoader(web_paths=[url_1, url_2, url_3])

# %%
# load the document

documents = loader.load()

# %%
len(documents)
# Out:
# 3

# %%
print(documents[2].page_content)
# Out:
# PDFPlumber integration - Docs by LangChainSkip to main contentJoin us May 13th & May 14th at Interrupt, the Agent Conference by LangChain. Buy tickets >Docs by LangChain home pageOpen sourceSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationPDFPlumber integrationDeep AgentsLangChainLangGraphIntegrationsLearnReferenceContributePythonLangChain integrationsAll providersPopular ProvidersOpenAIAnthropicGoogleAWSNVIDIAHugging FaceMicrosoftOllamaGroqIntegrations by componentChat modelsTools and toolkitsMiddlewareSandboxesCheckpointersRetrieversText splittersEmbedding modelsVector storesDocument loadersOn this pageOverviewIntegration detailsLoader featuresSetupCredentialsInstallationInitializationLoadLazy loadAPI referencePDFPlumber integrationCopy pageIntegrate with the PDFPlumber document loader using LangChain Python.Copy pageDocumentation IndexFetch the complete documentation index at: https://docs.langchain.com/llms.txtUse this file to discover all available pages before exploring further.Like PyMuPDF, the output Documents contain detailed metadata about the PDF and its pages, and returns one document per page.
# ​Overview
# ​Integration details
# ClassPackageLocalSerializableJS supportPDFPlumberLoaderlangchain-community✅❌❌
# ​Loader features
# SourceDocument Lazy LoadingNative Async SupportPDFPlumberLoader✅❌
# ​Setup
# ​Credentials
# No credentials are needed to use this loader.
# To enable automated tracing of your model calls, set your LangSmith API key:
# os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")
# os.environ["LANGSMITH_TRACING"] = "true"
#
# ​Installation
# Install langchain-community.
# pip install -qU langchain-community pdfplumber
#
# ​Initialization
# Now we can instantiate our model object and load documents:
# from langchain_community.document_loaders import PDFPlumberLoader
#
# loader = PDFPlumberLoader("./example_data/layout-parser-paper.pdf")
#
# ​Load
# docs = loader.load()
# docs[0]
#
# Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'file_path': './example_data/layout-parser-paper.pdf', 'page': 0, 'total_pages': 16, 'Author': '', 'CreationDate': 'D:20210622012710Z', 'Creator': 'LaTeX with hyperref', 'Keywords': '', 'ModDate': 'D:20210622012710Z', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'Producer': 'pdfTeX-1.40.21', 'Subject': '', 'Title': '', 'Trapped': 'False'}, page_content='LayoutParser: A Unified Toolkit for Deep\nLearning Based Document Image Analysis\nZejiang Shen1 ((cid:0)), Ruochen Zhang2, Melissa Dell3, Benjamin Charles Germain\nLee4, Jacob Carlson3, and Weining Li5\n1 Allen Institute for AI\nshannons@allenai.org\n2 Brown University\nruochen zhang@brown.edu\n3 Harvard University\n{melissadell,jacob carlson}@fas.harvard.edu\n4 University of Washington\nbcgl@cs.washington.edu\n5 University of Waterloo\nw422li@uwaterloo.ca\nAbstract. Recentadvancesindocumentimageanalysis(DIA)havebeen\nprimarily driven by the application of neural networks. Ideally, research\noutcomescouldbeeasilydeployedinproductionandextendedforfurther\ninvestigation. However, various factors like loosely organized codebases\nand sophisticated model configurations complicate the easy reuse of im-\nportantinnovationsbyawideaudience.Thoughtherehavebeenon-going\nefforts to improve reusability and simplify deep learning (DL) model\ndevelopmentindisciplineslikenaturallanguageprocessingandcomputer\nvision, none of them are optimized for challenges in the domain of DIA.\nThis represents a major gap in the existing toolkit, as DIA is central to\nacademicresearchacross awiderangeof disciplinesinthesocialsciences\nand humanities. This paper introduces LayoutParser, an open-source\nlibrary for streamlining the usage of DL in DIA research and applica-\ntions. The core LayoutParser library comes with a set of simple and\nintuitiveinterfacesforapplyingandcustomizingDLmodelsforlayoutde-\ntection,characterrecognition,andmanyotherdocumentprocessingtasks.\nTo promote extensibility, LayoutParser also incorporates a community\nplatform for sharing both pre-trained models and full document digiti-\nzation pipelines. We demonstrate that LayoutParser is helpful for both\nlightweight and large-scale digitization pipelines in real-word use cases.\nThe library is publicly available at https://layout-parser.github.io.\nKeywords: DocumentImageAnalysis·DeepLearning·LayoutAnalysis\n· Character Recognition · Open Source library · Toolkit.\n1 Introduction\nDeep Learning(DL)-based approaches are the state-of-the-art for a wide range of\ndocumentimageanalysis(DIA)tasksincludingdocumentimageclassification[11,\n1202\nnuJ\n12\n]VC.sc[\n2v84351.3012:viXra\n')
#
# print(docs[0].metadata)
#
# {'source': './example_data/layout-parser-paper.pdf', 'file_path': './example_data/layout-parser-paper.pdf', 'page': 0, 'total_pages': 16, 'Author': '', 'CreationDate': 'D:20210622012710Z', 'Creator': 'LaTeX with hyperref', 'Keywords': '', 'ModDate': 'D:20210622012710Z', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'Producer': 'pdfTeX-1.40.21', 'Subject': '', 'Title': '', 'Trapped': 'False'}
#
# ​Lazy load
# page = []
# for doc in loader.lazy_load():
#     page.append(doc)
#     if len(page) >= 10:
#         # do some paged operation, e.g.
#         # index.upsert(page)
#
#         page = []
#
#
# ​API reference
# For detailed documentation of all PDFPlumberLoader features and configurations head to the API reference
#
# Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Edit this page on GitHub or file an issue.Was this page helpful?YesNo⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyContact SalesCompanyHomeTrust CenterCareersBloggithubxlinkedinyoutube

# %%
pp(documents[2].metadata)
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber',
#  'title': 'PDFPlumber integration - Docs by LangChain',
#  'description': 'Integrate with the PDFPlumber document loader using LangChain '
#                 'Python.',
#  'language': 'en'}

# %% [markdown]
# #### **RecursiveUrlLoader**

# %%
from langchain_community.document_loaders import RecursiveUrlLoader

# %%
# create the loader

base_url = "https://docs.langchain.com/oss/python/integrations/document_loaders"

loader = RecursiveUrlLoader(
    url=base_url
)

# %%
# load the documents

documents = loader.load()
# Out:
# /Users/lokeshkv/data-engineering/learning/adv-rag-mastery/.venv/lib/python3.12/site-packages/langchain_community/document_loaders/recursive_url_loader.py:44: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(raw_html, "html.parser")

# %%
len(documents)
# Out:
# 95

# %%
pp(documents[10].page_content[:500])
# Out:
# ('<!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad '
#  'dark" data-banner-state="visible" data-assistant-state="closed" '
#  'data-page-mode="none" data-current-path="/"><head><meta '
#  'charSet="utf-8"/><meta name="viewport" content="width=device-width, '
#  'initial-scale=1, viewport-fit=cover"/><link rel="preload" '
#  'href="/mintlify-assets/_next/static/media/bb3ef058b751a6ad-s.p.woff2" '
#  'as="font" crossorigin="" type="font/woff2"/><link rel="preload" '
#  'href="/mintlify-assets/_next/static/media/c4b7')

# %%
pp(documents[0].metadata)
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Document loader integrations - Docs by LangChain',
#  'description': 'Integrate with document loaders using LangChain Python.',
#  'language': 'en'}

# %%
documents_lazy_load = loader.lazy_load()

# %%
documents_lazy_load
# Out:
# <generator object RecursiveUrlLoader._get_child_links_recursive at 0x11211fa70>

# %%
counter = 0

for document in documents_lazy_load:
    # stop condition
    
    # incerement the counter
    counter += 1
    
    # print metadata and page content
    print(document.page_content[0:300])
    pp(document.metadata)
# Out:
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/trello',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Trello integration - Docs by LangChain',
#  'description': 'Integrate with the Trello document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/google',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google integrations - Docs by LangChain',
#  'description': 'Integrate with Google using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/amazon_textract',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Amazon Textract integration - Docs by LangChain',
#  'description': 'Integrate with the Amazon Textract document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/huggingface',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Hugging Face integrations - Docs by LangChain',
#  'description': 'Integrate with Hugging Face using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/bshtml',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'BSHTMLLoader integration - Docs by LangChain',
#  'description': 'Integrate with the BSHTMLLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/chat/index',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Chat model integrations - Docs by LangChain',
#  'description': 'Integrate with chat models using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/telegram',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Telegram integration - Docs by LangChain',
#  'description': 'Integrate with the Telegram document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/microsoft_sharepoint',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Microsoft SharePoint integration - Docs by LangChain',
#  'description': 'Integrate with the Microsoft SharePoint document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/twitter',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Twitter integration - Docs by LangChain',
#  'description': 'Integrate with the Twitter document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/tencent_cos_file',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Tencent cos file integration - Docs by LangChain',
#  'description': 'Integrate with the Tencent cos file document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/groq',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Groq integrations - Docs by LangChain',
#  'description': 'Integrate with Groq using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/upstage',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Upstage integration - Docs by LangChain',
#  'description': 'Integrate with the Upstage document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/docling',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Docling integration - Docs by LangChain',
#  'description': 'Integrate with the Docling document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/mathpix',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'MathpixPDFLoader integration - Docs by LangChain',
#  'description': 'Integrate with the MathpixPDFLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/checkpointers',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Checkpointer integrations - Docs by LangChain',
#  'description': 'Integrate with checkpointer backends for LangGraph '
#                 'persistence.',
#  'language': 'en'}
# :root{--twoslash-border-color:#dbdfde;--twoslash-underline-color:currentColor;--twoslash-popup-bg:#f3f7f6;--twoslash-popup-color:inherit;--twoslash-popup-shadow:rgba(0,0,0,0.08) 0px 1px 4px;--twoslash-code-font:inherit;--twoslash-code-font-size:1em;--twoslash-matched-color:inherit;--twoslash-highlig
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/css/05d6d8fcb903870d.css?dpl=dpl_2RFNCe79XAhyhzSNRJpAmTSAp9Sz',
#  'content_type': 'text/css; charset=utf-8'}
# @font-face{font-family:Inter;font-style:italic;font-weight:100 900;font-display:swap;src:url(/mintlify-assets/_next/static/media/ea4faeba9f184c30-s.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-family:Inter;font-style:italic;f
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/css/9e8832c8599d2dba.css?dpl=dpl_2RFNCe79XAhyhzSNRJpAmTSAp9Sz',
#  'content_type': 'text/css; charset=utf-8'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/tencent_cos_directory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Tencent cos directory integration - Docs by LangChain',
#  'description': 'Integrate with the Tencent cos directory document loader '
#                 'using LangChain Python.',
#  'language': 'en'}
# wOF2�0���^��D�p?HVAR�i?MVAR^`?STAT�N'&�6/l
# ��@���0��>6$� �.�[l�q'�D�W���l����IU5}	7hv��\@�M]J�g�T�m�n$�6�����M*chS��Q����ffY�L�K���,&�N���ǒsY��䛄�N�� %΢F��h�bN�f�!�60�Cn�)B�@�Lk��f�4S�X�St�hfIY�.�g��޴k����ΰ��UR%���
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/media/e4af272ccee01ff0-s.p.woff2',
#  'content_type': 'font/woff2'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/figma',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Figma integration - Docs by LangChain',
#  'description': 'Integrate with the Figma document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# *,::backdrop,:after,:before{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/css/175c76c8cf5cd0c1.css?dpl=dpl_2RFNCe79XAhyhzSNRJpAmTSAp9Sz',
#  'content_type': 'text/css; charset=utf-8'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/middleware',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Middleware integrations - Docs by LangChain',
#  'description': 'Integrate with middleware using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/aws_s3_directory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'AWS s3 directory integration - Docs by LangChain',
#  'description': 'Integrate with the AWS s3 directory document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/vectorstores',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Vector store integrations - Docs by LangChain',
#  'description': 'Integrate with vector stores using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/dropbox',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Dropbox integration - Docs by LangChain',
#  'description': 'Integrate with the Dropbox document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pymupdf',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'PyMuPDFLoader integration - Docs by LangChain',
#  'description': 'Integrate with the PyMuPDFLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/unstructured_file',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Unstructured integration - Docs by LangChain',
#  'description': 'Integrate with the Unstructured document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/whatsapp_chat',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Whatsapp integration - Docs by LangChain',
#  'description': 'Integrate with the Whatsapp document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/deepagents/overview',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Deep Agents overview - Docs by LangChain',
#  'description': 'Build agents that can plan, use subagents, and leverage file '
#                 'systems for complex tasks',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/mastodon',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Mastodon integration - Docs by LangChain',
#  'description': 'Integrate with the Mastodon document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/discord',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Discord integration - Docs by LangChain',
#  'description': 'Integrate with the Discord document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/github',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'GitHub integration - Docs by LangChain',
#  'description': 'Integrate with the GitHub document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/undatasio',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Undatasio integration - Docs by LangChain',
#  'description': 'Integrate with the Undatasio document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'PyPDFLoader integration - Docs by LangChain',
#  'description': 'Integrate with the PyPDFLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# wOF2� | ���_�N��r?HVAR�L`?STAT�b'&�"/j
# ��8��.�0��06$� �L�[�_qOf\�ܭ�4!�(
# ���p9m˂q��8��zd����Td�4ܴݘ0�%x =ːZ1&�5ȴg3i�H�B^�r�i[�ل��6o�э"�&3��dJ)l?f���9Q'�<fFX�죗zq*�(�_��]�����pi?8�!�d���\֭�+H�I'����T��~/[���*X�]tԊ<�GB8DGit#����E�'2
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/media/bb3ef058b751a6ad-s.p.woff2',
#  'content_type': 'font/woff2'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/learn',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Learn - Docs by LangChain',
#  'description': 'Tutorials, conceptual guides, and resources to help you get '
#                 'started.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/polaris_ai_datainsight',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'PolarisAIDataInsightLoader integration - Docs by LangChain',
#  'description': 'Integrate with the PolarisAIDataInsightLoader document loader '
#                 'using LangChain Python.',
#  'language': 'en'}
# # Docs by LangChain
#
# > Documentation for LangSmith, Fleet, and our open source packages.
#
# ## Docs
#
# - [Create Connection](https://docs.langchain.com/api-reference/agent-connections-v2/create-connection.md)
# - [List Connections](https://docs.langchain.com/api-reference/agent-connections-v2/list-connect
# {'source': 'https://docs.langchain.com/llms.txt',
#  'content_type': 'text/plain; charset=utf-8'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/openai',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'OpenAI integrations - Docs by LangChain',
#  'description': 'Integrate with OpenAI using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/sitemap',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'SitemapLoader integration - Docs by LangChain',
#  'description': 'Integrate with the SitemapLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pymupdf4llm',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'PyMuPDF4LLMLoader integration - Docs by LangChain',
#  'description': 'Integrate with the PyMuPDF4LLMLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'PDFPlumber integration - Docs by LangChain',
#  'description': 'Integrate with the PDFPlumber document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/slack',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Slack integration - Docs by LangChain',
#  'description': 'Integrate with the Slack document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/contributing/overview',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Contributing - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/splitters',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Text splitter integrations - Docs by LangChain',
#  'description': 'Integrate with text splitters using LangChain.',
#  'language': 'en'}
# wOF2ɴ���=�^��z�p?HVAR?MVAR^`?STAT�J'&�6/l
# ��,�"(�U��]��Re��q�Q���z">�����J�;"��0N�9������f5���6uY��*�1+�������������d"cy	pI۶P|�n۫��bJ9�Z��mfnq1�^���C�
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/media/c4b700dcb2187787-s.p.woff2',
#  'content_type': 'font/woff2'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/json',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'JSONLoader integration - Docs by LangChain',
#  'description': 'Integrate with the JSONLoader document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/use-these-docs',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Use docs programmatically - Docs by LangChain',
#  'description': 'Connect LangChain documentation to your AI tools and '
#                 'workflows',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/web_base',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'WebBaseLoader integration - Docs by LangChain',
#  'description': 'Integrate with the WebBaseLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/ollama',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Ollama integrations - Docs by LangChain',
#  'description': 'Integrate with Ollama using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/firecrawl',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'FireCrawl integration - Docs by LangChain',
#  'description': 'Integrate with the FireCrawl document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/agentql',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'AgentQLLoader integration - Docs by LangChain',
#  'description': 'Integrate with the AgentQLLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/roam',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Roam integration - Docs by LangChain',
#  'description': 'Integrate with the Roam document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/azure_ai_data',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Azure AI data integration - Docs by LangChain',
#  'description': 'Integrate with the Azure AI data document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/anthropic',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Anthropic (Claude) integrations - Docs by LangChain',
#  'description': 'Integrate with Anthropic (Claude) using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/chat',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Chat model integrations - Docs by LangChain',
#  'description': 'Integrate with chat models using LangChain Python.',
#  'language': 'en'}
# <?xml version="1.0" encoding="UTF-8"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" xmlns:news="http://www.google.com/schemas/sitemap-news/0.9" xmlns:xhtml="http://www.w3.org/1999/xhtml" xmlns:image="http://www.google.com/schemas/sitemap-image/1.1" xmlns:video="http://www.google.com/s
# {'source': 'https://docs.langchain.com/sitemap.xml', 'content_type': 'text/xml'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pdfminer',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'PDFMinerLoader integration - Docs by LangChain',
#  'description': 'Integrate with the PDFMinerLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/hyperbrowser',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'HyperbrowserLoader integration - Docs by LangChain',
#  'description': 'Integrate with the HyperbrowserLoader document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/nvidia',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'NVIDIA - Docs by LangChain',
#  'description': 'Integrate with NVIDIA using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/huawei_obs_directory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Huawei obs directory integration - Docs by LangChain',
#  'description': 'Integrate with the Huawei obs directory document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/aws',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'AWS (Amazon) integrations - Docs by LangChain',
#  'description': 'Integrate with AWS (Amazon) using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/all_providers',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'All LangChain Python integration providers - Docs by LangChain',
#  'language': 'en'}
# wOF2yp|0y?FFTM���n�"`�&
# �*",q5[���t��Z��6,�U�}.��c��bt�V�a�l���P��bvU��˜]*�acG#��͈��+V���3�y&Ba��U�	�'kj?�.6�Z/��*A����A�[�!�H�P�pM,��؃���&AR%7�hb�����
# {'source': 'https://docs.langchain.com/fonts/TWKLausanne-700.woff2',
#  'content_type': 'application/octet-stream, font/woff2'}
# (()=>{"use strict";var e={},a={};function d(c){var f=a[c];if(void 0!==f)return f.exports;var b=a[c]={id:c,loaded:!1,exports:{}},t=!0;try{e[c].call(b.exports,b,b.exports,d),t=!1}finally{t&&delete a[c]}return b.loaded=!0,b.exports}d.m=e,(()=>{var e=[];d.O=(a,c,f,b)=>{if(c){b=b||0;for(var t=e.length;t>
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/chunks/webpack-367d851647758882.js?dpl=dpl_2RFNCe79XAhyhzSNRJpAmTSAp9Sz',
#  'content_type': 'application/javascript; charset=utf-8'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_cloud_storage_file',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google cloud storage file integration - Docs by LangChain',
#  'description': 'Integrate with the Google cloud storage file document loader '
#                 'using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/reddit',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Reddit integration - Docs by LangChain',
#  'description': 'Integrate with the Reddit document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/facebook_chat',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Facebook integration - Docs by LangChain',
#  'description': 'Integrate with the Facebook document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/sandboxes',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Sandbox integrations - Docs by LangChain',
#  'description': 'Integrate with sandbox providers using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_cloud_storage_directory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google cloud storage directory integration - Docs by LangChain',
#  'description': 'Integrate with the Google cloud storage directory document '
#                 'loader using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_drive',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google drive integration - Docs by LangChain',
#  'description': 'Integrate with the Google drive document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/apify_dataset',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Apify dataset integration - Docs by LangChain',
#  'description': 'Integrate with the Apify dataset document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/embeddings',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Embedding model integrations - Docs by LangChain',
#  'description': 'Integrate with embedding models using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/>
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/quip',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Quip integration - Docs by LangChain',
#  'description': 'Integrate with the Quip document loader using LangChain '
#                 'Python.',
#  'language': 'en'}

# %%
counter
# Out:
# 74

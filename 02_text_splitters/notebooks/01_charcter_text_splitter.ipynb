# %%
from pprint import pp
from langchain_text_splitters import CharacterTextSplitter

# %%
text = """
Artificial intelligence is transforming technology and shaping the future. 
Machine learning algorithms are becoming more sophisticated every day.
Deep learning models can now process vast amounts of data efficiently.

Natural language processing has made significant strides in recent years.
Computer vision systems can now identify objects with remarkable accuracy.
Reinforcement learning is enabling robots to learn complex tasks autonomously.

The impact of AI extends across multiple industries including healthcare, finance, and transportation.
Ethical considerations around AI development are becoming increasingly important.
Researchers are working on making AI systems more transparent and explainable.
"""

# %%
## Create the Splitter Instance

splitter = CharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=0,
    length_function=len,
    separator=""
)

# %%
#Split the Text

chunks = splitter.split_text(text=text)

pp(chunks)
# Out:
# ['Artificial intelligence is transforming technology and shaping the future. \n'
#  'Machine learning algori',
#  'thms are becoming more sophisticated every day.\n'
#  'Deep learning models can now process vast amounts of',
#  'data efficiently.\n'
#  '\n'
#  'Natural language processing has made significant strides in recent years.\n'
#  'Comput',
#  'er vision systems can now identify objects with remarkable accuracy.\n'
#  'Reinforcement learning is enabl',
#  'ing robots to learn complex tasks autonomously.\n'
#  '\n'
#  'The impact of AI extends across multiple industries',
#  'including healthcare, finance, and transportation.\n'
#  'Ethical considerations around AI development are',
#  'becoming increasingly important.\n'
#  'Researchers are working on making AI systems more transparent and',
#  'explainable.']

# %%
print(f"Number of Chunks: {len(chunks)}")
# Out:
# Number of Chunks: 8

# %%
from termcolor import COLORS, colored
from random import choice

# %%
print(COLORS)
# Out:
# {'black': 30, 'grey': 30, 'red': 31, 'green': 32, 'yellow': 33, 'blue': 34, 'magenta': 35, 'cyan': 36, 'light_grey': 37, 'dark_grey': 90, 'light_red': 91, 'light_green': 92, 'light_yellow': 93, 'light_blue': 94, 'light_magenta': 95, 'light_cyan': 96, 'white': 97}

# %%
colors_list = list(COLORS.keys())[2:8]

colors_list
# Out:
# ['red', 'green', 'yellow', 'blue', 'magenta', 'cyan']

# %%
# display the chunks

def display_chunks(chunks):
    colors_list = list(COLORS.keys())[2:8]
    print(f"Total Number of Chunks: {len(chunks)}")
    for num, chunk in enumerate(chunks, 1):
        print(f"Chunk {num}: Length {len(chunk)} chars")
        print(colored(text=chunk, color=choice(colors_list)), end="\n\n")

# %%
display_chunks(chunks)
# Out:
# Total Number of Chunks: 8
# Chunk 1: Length 99 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algori
#
# Chunk 2: Length 100 chars
# thms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of
#
# Chunk 3: Length 99 chars
# data efficiently.
#
# Natural language processing has made significant strides in recent years.
# Comput
#
# Chunk 4: Length 100 chars
# er vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabl
#
# Chunk 5: Length 100 chars
# ing robots to learn complex tasks autonomously.
#
# The impact of AI extends across multiple industries
#
# Chunk 6: Length 99 chars
# including healthcare, finance, and transportation.
# Ethical considerations around AI development are
#
# Chunk 7: Length 98 chars
# becoming increasingly important.
# Researchers are working on making AI systems more transparent and
#
# Chunk 8: Length 12 chars
# explainable.

# %%
def create_chunks(text: str, chunk_size: int, 
                  separator: str, chunk_overlap: int = 0) -> list[str]:
    # create splitter
    splitter = CharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separator=separator
    )
    # split text
    chunks = splitter.split_text(text=text)
    return chunks

# %%
display_chunks(create_chunks(text, 100, ""))
# Out:
# Total Number of Chunks: 8
# Chunk 1: Length 99 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algori
#
# Chunk 2: Length 100 chars
# thms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of
#
# Chunk 3: Length 99 chars
# data efficiently.
#
# Natural language processing has made significant strides in recent years.
# Comput
#
# Chunk 4: Length 100 chars
# er vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabl
#
# Chunk 5: Length 100 chars
# ing robots to learn complex tasks autonomously.
#
# The impact of AI extends across multiple industries
#
# Chunk 6: Length 99 chars
# including healthcare, finance, and transportation.
# Ethical considerations around AI development are
#
# Chunk 7: Length 98 chars
# becoming increasingly important.
# Researchers are working on making AI systems more transparent and
#
# Chunk 8: Length 12 chars
# explainable.

# %%
display_chunks(create_chunks(text, 300, ""))
# Out:
# Total Number of Chunks: 3
# Chunk 1: Length 299 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of data efficiently.
#
# Natural language processing has made significant strides in recent years.
# Comput
#
# Chunk 2: Length 300 chars
# er vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabling robots to learn complex tasks autonomously.
#
# The impact of AI extends across multiple industries including healthcare, finance, and transportation.
# Ethical considerations around AI development are
#
# Chunk 3: Length 111 chars
# becoming increasingly important.
# Researchers are working on making AI systems more transparent and explainable.

# %%
display_chunks(create_chunks(text, 50, ""))
# Out:
# Total Number of Chunks: 15
# Chunk 1: Length 49 chars
# Artificial intelligence is transforming technolog
#
# Chunk 2: Length 50 chars
# y and shaping the future.
# Machine learning algori
#
# Chunk 3: Length 50 chars
# thms are becoming more sophisticated every day.
# De
#
# Chunk 4: Length 50 chars
# ep learning models can now process vast amounts of
#
# Chunk 5: Length 49 chars
# data efficiently.
#
# Natural language processing ha
#
# Chunk 6: Length 50 chars
# s made significant strides in recent years.
# Comput
#
# Chunk 7: Length 50 chars
# er vision systems can now identify objects with re
#
# Chunk 8: Length 50 chars
# markable accuracy.
# Reinforcement learning is enabl
#
# Chunk 9: Length 50 chars
# ing robots to learn complex tasks autonomously.
#
# T
#
# Chunk 10: Length 50 chars
# he impact of AI extends across multiple industries
#
# Chunk 11: Length 49 chars
# including healthcare, finance, and transportation
#
# Chunk 12: Length 50 chars
# .
# Ethical considerations around AI development are
#
# Chunk 13: Length 48 chars
# becoming increasingly important.
# Researchers are
#
# Chunk 14: Length 49 chars
# working on making AI systems more transparent and
#
# Chunk 15: Length 12 chars
# explainable.

# %%
# lets use word boundaries

display_chunks(create_chunks(text, 100, " "))
# Out:
# Total Number of Chunks: 8
# Chunk 1: Length 92 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning
#
# Chunk 2: Length 95 chars
# algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast
#
# Chunk 3: Length 96 chars
# amounts of data efficiently.
#
# Natural language processing has made significant strides in recent
#
# Chunk 4: Length 95 chars
# years.
# Computer vision systems can now identify objects with remarkable accuracy.
# Reinforcement
#
# Chunk 5: Length 97 chars
# learning is enabling robots to learn complex tasks autonomously.
#
# The impact of AI extends across
#
# Chunk 6: Length 100 chars
# multiple industries including healthcare, finance, and transportation.
# Ethical considerations around
#
# Chunk 7: Length 96 chars
# AI development are becoming increasingly important.
# Researchers are working on making AI systems
#
# Chunk 8: Length 33 chars
# more transparent and explainable.

# %%
print(text)
# Out:
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of data efficiently.
#
# Natural language processing has made significant strides in recent years.
# Computer vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabling robots to learn complex tasks autonomously.
#
# The impact of AI extends across multiple industries including healthcare, finance, and transportation.
# Ethical considerations around AI development are becoming increasingly important.
# Researchers are working on making AI systems more transparent and explainable.

# %%
# chunking based on paragraph separator

display_chunks(create_chunks(text, 100, "\n\n"))
# Out:
# Created a chunk of size 218, which is longer than the specified 100
# Created a chunk of size 227, which is longer than the specified 100
# Total Number of Chunks: 3
# Chunk 1: Length 217 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of data efficiently.
#
# Chunk 2: Length 227 chars
# Natural language processing has made significant strides in recent years.
# Computer vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabling robots to learn complex tasks autonomously.
#
# Chunk 3: Length 263 chars
# The impact of AI extends across multiple industries including healthcare, finance, and transportation.
# Ethical considerations around AI development are becoming increasingly important.
# Researchers are working on making AI systems more transparent and explainable.

# %%
display_chunks(create_chunks(text, 250, "\n\n"))
# Out:
# Total Number of Chunks: 3
# Chunk 1: Length 217 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of data efficiently.
#
# Chunk 2: Length 227 chars
# Natural language processing has made significant strides in recent years.
# Computer vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabling robots to learn complex tasks autonomously.
#
# Chunk 3: Length 263 chars
# The impact of AI extends across multiple industries including healthcare, finance, and transportation.
# Ethical considerations around AI development are becoming increasingly important.
# Researchers are working on making AI systems more transparent and explainable.

# %%
def display_chunks_with_overlaps(chunks, chunk_overlap):
    if not chunk_overlap:
        raise(ValueError("Chunk Overlap cannot be 0"))
    
    # create vars
    overlap_text = ""
    overlap_color = "white"
    colors_list = list(COLORS.keys())[2:8]
    
    print(f"Total Number of Chunks: {len(chunks)}")
    for num, chunk in enumerate(chunks, 1):
        print(f"Chunk {num}: Length {len(chunk)} chars")
        if num == 1:
            # print the chunk without overlap
            non_overlap_text = chunk[0:-chunk_overlap]
            overlap_text = chunk[-chunk_overlap:]
            print(colored(non_overlap_text, choice(colors_list)),
                  colored(overlap_text,overlap_color),
                  sep="",end="\n\n")
        else:
            # print the overlap text at start of chunk
            print(colored(overlap_text, overlap_color), end="")
            # print non overlap text
            non_overlap_text = chunk[chunk_overlap:-chunk_overlap]
            print(colored(non_overlap_text, choice(colors_list)), end="")
            # print overlap text at end of chunk
            overlap_text = chunk[-chunk_overlap:]
            print(colored(overlap_text, overlap_color), end="\n\n")

# %%
display_chunks(
    chunks=create_chunks(
        text=text,
        chunk_size=100,
        separator=""
    )
)
# Out:
# Total Number of Chunks: 8
# Chunk 1: Length 99 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algori
#
# Chunk 2: Length 100 chars
# thms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of
#
# Chunk 3: Length 99 chars
# data efficiently.
#
# Natural language processing has made significant strides in recent years.
# Comput
#
# Chunk 4: Length 100 chars
# er vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabl
#
# Chunk 5: Length 100 chars
# ing robots to learn complex tasks autonomously.
#
# The impact of AI extends across multiple industries
#
# Chunk 6: Length 99 chars
# including healthcare, finance, and transportation.
# Ethical considerations around AI development are
#
# Chunk 7: Length 98 chars
# becoming increasingly important.
# Researchers are working on making AI systems more transparent and
#
# Chunk 8: Length 12 chars
# explainable.

# %%
display_chunks_with_overlaps(
    chunks=create_chunks(
        text=text,
        chunk_size=100,
        separator="",
        chunk_overlap=20
    ),
     chunk_overlap=20
)
# Out:
# Total Number of Chunks: 9
# Chunk 1: Length 99 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algori
#
# Chunk 2: Length 100 chars
# hine learning algorithms are becoming more sophisticated every day.
# Deep learning models can now pro
#
# Chunk 3: Length 100 chars
# g models can now process vast amounts of data efficiently.
#
# Natural language processing has made sig
#
# Chunk 4: Length 100 chars
# cessing has made significant strides in recent years.
# Computer vision systems can now identify objec
#
# Chunk 5: Length 99 chars
# n now identify objects with remarkable accuracy.
# Reinforcement learning is enabling robots to learn
#
# Chunk 6: Length 100 chars
# ling robots to learncomplex tasks autonomously.
#
# The impact of AI extends across multiple industries
#
# Chunk 7: Length 99 chars
#  multiple industriesincluding healthcare, finance, and transportation.
# Ethical considerations aroun
#
# Chunk 8: Length 100 chars
# considerations around AI development are becoming increasingly important.
# Researchers are working on
#
# Chunk 9: Length 72 chars
# chers are working on making AI systems more transparent and explainable.

# %% [markdown]
# ### **Token Based Splitting**

# %%
## Create Token Based Splitter

token_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    encoding_name='cl100k_base',
    chunk_size=50,
    chunk_overlap=5
)

# %%
## Split the text

pp(
    token_splitter.split_text(
        text=text
    )
)
# Out:
# ['Artificial intelligence is transforming technology and shaping the future. \n'
#  'Machine learning algorithms are becoming more sophisticated every day.\n'
#  'Deep learning models can now process vast amounts of data efficiently.',
#  'Natural language processing has made significant strides in recent years.\n'
#  'Computer vision systems can now identify objects with remarkable accuracy.\n'
#  'Reinforcement learning is enabling robots to learn complex tasks '
#  'autonomously.',
#  'The impact of AI extends across multiple industries including healthcare, '
#  'finance, and transportation.\n'
#  'Ethical considerations around AI development are becoming increasingly '
#  'important.\n'
#  'Researchers are working on making AI systems more transparent and '
#  'explainable.']

# %% [markdown]
# ### **Splitting Documents**

# %%
from langchain_core.documents import Document

# %%
docs = [
    Document(
        page_content=text,
        metadata={
            "source" : "Text on AI"
        }
    )
]

# %%
print(docs)
# Out:
# [Document(metadata={'source': 'Text on AI'}, page_content='\nArtificial intelligence is transforming technology and shaping the future. \nMachine learning algorithms are becoming more sophisticated every day.\nDeep learning models can now process vast amounts of data efficiently.\n\nNatural language processing has made significant strides in recent years.\nComputer vision systems can now identify objects with remarkable accuracy.\nReinforcement learning is enabling robots to learn complex tasks autonomously.\n\nThe impact of AI extends across multiple industries including healthcare, finance, and transportation.\nEthical considerations around AI development are becoming increasingly important.\nResearchers are working on making AI systems more transparent and explainable.\n')]

# %%
splitter = CharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    separator=""
)

# %%
chunks = splitter.split_documents(docs)

# %%
chunks
# Out:
# [Document(metadata={'source': 'Text on AI'}, page_content='Artificial intelligence is transforming technology and shaping the future. \nMachine learning algori'),
#  Document(metadata={'source': 'Text on AI'}, page_content='hine learning algorithms are becoming more sophisticated every day.\nDeep learning models can now pro'),
#  Document(metadata={'source': 'Text on AI'}, page_content='g models can now process vast amounts of data efficiently.\n\nNatural language processing has made sig'),
#  Document(metadata={'source': 'Text on AI'}, page_content='cessing has made significant strides in recent years.\nComputer vision systems can now identify objec'),
#  Document(metadata={'source': 'Text on AI'}, page_content='n now identify objects with remarkable accuracy.\nReinforcement learning is enabling robots to learn'),
#  Document(metadata={'source': 'Text on AI'}, page_content='ing robots to learn complex tasks autonomously.\n\nThe impact of AI extends across multiple industries'),
#  Document(metadata={'source': 'Text on AI'}, page_content='multiple industries including healthcare, finance, and transportation.\nEthical considerations aroun'),
#  Document(metadata={'source': 'Text on AI'}, page_content='considerations around AI development are becoming increasingly important.\nResearchers are working on'),
#  Document(metadata={'source': 'Text on AI'}, page_content='chers are working on making AI systems more transparent and explainable.')]
